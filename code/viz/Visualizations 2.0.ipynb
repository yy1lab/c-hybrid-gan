# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
test_logs_rmc = pd.read_csv('../../results/c_hybrid_gan/logs/test_logs.csv')
test_result_logs_rmc = pd.read_csv('../../results/c_hybrid_gan/logs/test_result_logs.csv')

# %%
res = test_logs_rmc.groupby('epoch').mean()

# %%
X = 39
YMIN = 0.15
YMAX = 0.85
COLOR = 'k'
LINESTYLE = '--'

# %%
rcParams['figure.dpi'] = 400

plt.subplot(2, 2, 1)
plt.plot(res['selfBLEU_2'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Self-BLEU-2')

plt.subplot(2, 2, 2)
plt.plot(res['selfBLEU_3'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Self-BLEU-3')

plt.subplot(2, 2, 3)
plt.plot(res['selfBLEU_4'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Self-BLEU-4')

plt.subplot(2, 2, 4)
plt.plot(res['selfBLEU_5'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Self-BLEU-5')

plt.tight_layout()
plt.savefig('./figures/rmc_self_bleu_trend.png')

# %%
rcParams['figure.dpi'] = 400

plt.subplot(2, 2, 1)
plt.plot(res['pMMD'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Pitch MMD')

plt.subplot(2, 2, 2)
plt.plot(res['dMMD'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Duration MMD')

plt.subplot(2, 2, 3)
plt.plot(res['rMMD'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Rest MMD')

plt.subplot(2, 2, 4)
plt.plot(res['oMMD'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Overall MMD')

plt.tight_layout()
plt.savefig('./figures/rmc_mmd_trend.png')

# %%
plt.figure(figsize=(4, 3))
rcParams['figure.dpi'] = 400

plt.plot(res['oMMD'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Overall MMD')
plt.tight_layout()
plt.savefig('./figures/rmc_overall_mmd_trend.png')

# %%
stats = test_result_logs_rmc.groupby('method').agg(['mean', 'std'])
stats.loc['CHGAN']
# Out:
# seed                 mean    173.500000
#                      std       1.722237
# run_id               mean      4.500000
#                      std       2.896520
# p_mmd                mean      0.001183
#                      std       0.000863
# d_mmd                mean      0.002894
#                      std       0.003084
# r_mmd                mean      0.001950
#                      std       0.001291
# o_mmd                mean      0.006027
#                      std       0.003507
# stats_scale          mean      1.000000
#                      std       0.000000
# stats_repetitions_2  mean      6.616127
#                      std       0.343529
# stats_repetitions_3  mean      2.819220
#                      std       0.275025
# stats_span           mean     11.960958
#                      std       0.525082
# stats_unique_tones   mean      6.033222
#                      std       0.181720
# stats_avg_rest       mean      0.745306
#                      std       0.087591
# num_of_null_rest     mean     15.801443
#                      std       0.210651
# songlength           mean     43.229262
#                      std       1.183432
# Name: CHGAN, dtype: float64

# %%
stats = test_result_logs_rmc.groupby('method').agg(['mean', 'std'])
stats.loc['CHMLE']
# Out:
# seed                 mean    173.500000
#                      std       1.722237
# run_id               mean      4.500000
#                      std       2.896520
# p_mmd                mean      0.054021
#                      std       0.010287
# d_mmd                mean      0.007885
#                      std       0.006399
# r_mmd                mean      0.017335
#                      std       0.007448
# o_mmd                mean      0.079240
#                      std       0.011438
# stats_scale          mean      1.000000
#                      std       0.000000
# stats_repetitions_2  mean      6.314431
#                      std       0.363628
# stats_repetitions_3  mean      2.437139
#                      std       0.264180
# stats_span           mean     13.532699
#                      std       0.519698
# stats_unique_tones   mean      6.195449
#                      std       0.151040
# stats_avg_rest       mean      1.122079
#                      std       0.103371
# num_of_null_rest     mean     13.150222
#                      std       1.439655
# songlength           mean     51.855102
#                      std       2.297895
# Name: CHMLE, dtype: float64

# %%
# end of notebook
