# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
test_logs_rmc = pd.read_csv('../../results/c_hybrid_gan/logs/test_logs.csv')
test_result_logs_rmc = pd.read_csv('../../results/c_hybrid_gan/logs/test_result_logs.csv')

# %%
res = test_logs_rmc.groupby('epoch').mean()

# %%
X = 39
YMIN = 0.15
YMAX = 0.85
COLOR = 'k'
LINESTYLE = '--'

# %%
rcParams['figure.dpi'] = 400

plt.subplot(2, 2, 1)
plt.plot(res['selfBLEU_2'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Self-BLEU-2')

plt.subplot(2, 2, 2)
plt.plot(res['selfBLEU_3'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Self-BLEU-3')

plt.subplot(2, 2, 3)
plt.plot(res['selfBLEU_4'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Self-BLEU-4')

plt.subplot(2, 2, 4)
plt.plot(res['selfBLEU_5'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Self-BLEU-5')

plt.tight_layout()
plt.savefig('./figures/rmc_self_bleu_trend.png')

# %%
rcParams['figure.dpi'] = 400

plt.subplot(2, 2, 1)
plt.plot(res['pMMD'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Pitch MMD')

plt.subplot(2, 2, 2)
plt.plot(res['dMMD'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Duration MMD')

plt.subplot(2, 2, 3)
plt.plot(res['rMMD'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Rest MMD')

plt.subplot(2, 2, 4)
plt.plot(res['oMMD'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Overall MMD')

plt.tight_layout()
plt.savefig('./figures/rmc_mmd_trend.png')

# %%
plt.figure(figsize=(4, 3))
rcParams['figure.dpi'] = 400

plt.plot(res['oMMD'])
plt.axvline(x=X, ymin=YMIN, ymax=YMAX, color=COLOR, linestyle=LINESTYLE)
plt.xlabel('epochs')
plt.ylabel('Overall MMD')
plt.tight_layout()
plt.savefig('./figures/rmc_overall_mmd_trend.png')

# %%
stats = test_result_logs_rmc.groupby('method').agg(['mean', 'std'])
stats.loc['C-Hybrid-GAN']
# Out:
# seed                 mean    100.000000
#                      std       0.000000
# run_id               mean      2.500000
#                      std       1.870829
# selfBLEU_2           mean      0.607890
#                      std       0.012181
# selfBLEU_3           mean      0.291080
#                      std       0.013888
# selfBLEU_4           mean      0.113155
#                      std       0.013513
# selfBLEU_5           mean      0.037205
#                      std       0.011947
# pMMD                 mean     -0.000368
#                      std       0.000201
# dMMD                 mean      0.000050
#                      std       0.000320
# rMMD                 mean      0.000984
#                      std       0.000530
# oMMD                 mean      0.001558
#                      std       0.000482
# stats_scale          mean      1.000000
#                      std       0.000000
# stats_repetitions_2  mean      2.996825
#                      std       0.047838
# stats_repetitions_3  mean      1.194444
#                      std       0.058232
# stats_span           mean      9.021905
#                      std       0.153077
# stats_unique_tones   mean      4.715079
#                      std       0.036636
# stats_avg_rest       mean      0.708915
#                      std       0.010986
# num_of_null_rest     mean      9.569048
#                      std       0.053692
# songlength           mean     25.436627
#                      std       0.207198
# Name: C-Hybrid-GAN, dtype: float64

# %%
stats = test_result_logs_rmc.groupby('method').agg(['mean', 'std'])
stats.loc['C-Hybrid-MLE']
# Out:
# seed                 mean    100.000000
#                      std       0.000000
# run_id               mean      2.500000
#                      std       1.870829
# selfBLEU_2           mean      0.571266
#                      std       0.011635
# selfBLEU_3           mean      0.249320
#                      std       0.015806
# selfBLEU_4           mean      0.090321
#                      std       0.017503
# selfBLEU_5           mean      0.029606
#                      std       0.012826
# pMMD                 mean      0.000812
#                      std       0.000240
# dMMD                 mean      0.001111
#                      std       0.000202
# rMMD                 mean      0.000216
#                      std       0.000134
# oMMD                 mean      0.002139
#                      std       0.000315
# stats_scale          mean      1.000000
#                      std       0.000000
# stats_repetitions_2  mean      2.609841
#                      std       0.060218
# stats_repetitions_3  mean      0.858730
#                      std       0.036364
# stats_span           mean      9.460317
#                      std       0.107390
# stats_unique_tones   mean      4.925714
#                      std       0.034015
# stats_avg_rest       mean      0.842804
#                      std       0.017282
# num_of_null_rest     mean      9.038571
#                      std       0.047557
# songlength           mean     27.510119
#                      std       0.266401
# Name: C-Hybrid-MLE, dtype: float64

# %%
# end of notebook
